# %%
from crewai import Crew, Process, Agent, Task

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-deepseek-486e32dcfc3e4623ba2744b715bf46a4"
os.environ["OPENAI_API_BASE"] = "https://api.deepseek.com"

# %%
doctor_agent = Agent(
    role="Doctor escritor de blog sobre anatomia humana",
    goal="Escrever um blog sobre anatomia humana com 50 linhas",
    backstory="Voce e um medico especialista em anatomia humana com 20 anos de experiencia",
    verbose=True,
    llm="deepseek/deepseek-chat"
)

# %%
editor_task = Task(
    name="Escrever um blog sobre anatomia humana  com 50 linhas",
    description="Criar um artigo informativo sobre a anatomia humana  com 50 linhas, incluindo sistemas, órgãos e suas funções.",
    agent=doctor_agent,
    expected_output="Um artigo detalhado sobre anatomia humana  com 50 linhas, adequado para um público leigo."
)

# %%
blog_crew = Crew(
    agents=[doctor_agent],
    tasks=[editor_task],
    processes=Process.sequential
    )

# %%
result = blog_crew.kickoff()
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Doctor escritor de blog sobre anatomia humana                                                           │
# │                                                                                                                 │
# │  Task: Criar um artigo informativo sobre a anatomia humana  com 50 linhas, incluindo sistemas, órgãos e suas    │
# │  funções.                                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...
